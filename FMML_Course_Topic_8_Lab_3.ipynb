# %% [markdown]
# <a href="https://colab.research.google.com/github/rammahesh28122003/FMML-COURSE-ASSIGNMENTSS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-08 06:32:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   298MB/s    in 0.2s
#
# 2023-05-08 06:32:56 (298 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24630   1409.6235v1  Although the human visual system is surprising...    cs
# 21664   1306.3574v1  The strategy of early stopping is a regulariza...  stat
# 11296  1507.07105v2  Subspace clustering refers to the problem of c...  stat
# 12370  1712.08449v1  We introduce a simple algorithm, True Asymptot...  stat
# 8163    1403.7057v1  We present LS-CRF, a new method for very effic...    cs
# ...             ...                                                ...   ...
# 32252   1401.5136v1  Over the past few years, Multi-Kernel Learning...    cs
# 20295  1508.00879v1  The fundamental problem underlying all multi-c...    cs
# 33104  1802.04948v1  Neural networks have been shown to be an effec...    cs
# 5488    1109.0455v1  This paper proposes a novel kernel approach to...  stat
# 7635   1802.05846v1  Model selection on validation data is an essen...  stat
#
#                                                    title  year  \
# 24630                     Detecting People in Cubist Art  2014
# 21664  Early stopping and non-parametric regression: ...  2013
# 11296         Dimensionality-reduced subspace clustering  2015
# 12370      True Asymptotic Natural Gradient Optimization  2017
# 8163   Closed-Form Training of Conditional Random Fie...  2014
# ...                                                  ...   ...
# 32252  A Unifying Framework for Typical Multi-Task Mu...  2014
# 20295  Qualitative Decision Methods for Multi-Attribu...  2015
# 33104   Graph2Seq: Scalable Learning Dynamics for Graphs  2018
# 5488   Gradient-based kernel dimension reduction for ...  2011
# 7635       Train on Validation: Squeezing the Data Lemon  2018
#
#                                                 keywords
# 24630  [surprisingly, distortion, recognizing, evalua...
# 21664  [regularization, technique, iterative, algorit...
# 11296  [clustering, clustering, unlabeled, dimensiona...
# 12370  [introduce, algorithm, asymptotic, optimizatio...
# 8163   [efficient, conditional, expressions, likeliho...
# ...                                                  ...
# 32252  [significant, attention, selection, techniques...
# 20295  [fundamental, underlying, dominance, alternati...
# 33104  [effective, algorithms, structured, representa...
# 5488   [dimension, reduction, supervised, dimension, ...
# 7635   [selection, validation, essential, validation,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24630    [surprisingly, distortion, recognizing, evalua...
# 21664    [regularization, technique, iterative, algorit...
# 11296    [clustering, clustering, unlabeled, dimensiona...
# 12370    [introduce, algorithm, asymptotic, optimizatio...
# 8163     [efficient, conditional, expressions, likeliho...
#                                ...
# 39587    [implement, autonomous, navigation, algorithms...
# 21526    [algorithm, motivated, experimental, algorithm...
# 15076    [aggregation, identification, sentiment, simul...
# 35977    [introduces, justification, programming, justi...
# 16027    [recognizing, relations, beneficial, distribut...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8687 words.
# Out of those 4497 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bac085bb-5d60-412a-ab65-5e2eaaca1fe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bac085bb-5d60-412a-ab65-5e2eaaca1fe0")) {                    Plotly.newPlot(                        "bac085bb-5d60-412a-ab65-5e2eaaca1fe0",                        [{"x":["distortion","robustness","comparing","evaluations","similarly","surprisingly","perception","recognizing","flexibility","determine","outperforms","degradation","increasingly","annotators","algorithms","deformations","distorted","detecting","demonstrate","detection","paintings","performance","significantly","detectors","representation","fragmentation","recognize","resulting","simulation","iterative","algorithm","regression","connection","smoothness","estimator","validation","dependent","regularization","technique","reproducing","establish","including","parametric","favorably","reduction","observations","available","thresholding","analytical","unlabeled","dimensional","illustrated","constraints","orientations","clustering","synthetic","specifically","simulations","dimensions","undersampling","computational","desirable","requirements","extensive","acquisition","fundamentally","theoretical","complexity","incurring","experiments","subspaces","mechanism","principles","projection","dimensionality","orthogonal","significant","complement","dimension","asymptotic","estimation","lightweight","quadratic","introduce","parameter","arbitrarily","sometimes","asymptotically","optimization","stochastic","converges","linearization","approximate","different","particular","graphical","likelihood","contribution","generative","inference","parameters","expression","segmentation","indicating","achieving","predictors","promising","independent","supervised","conditional","expressions","magnitude","annotations","previously","possibilities","directions","conventional","efficient","problematic","probabilistic","properties","classification","possesses","selection","prediction","composing","statistical","convenient","sophisticated","multivariate","selecting","substantial","generalization","classical","minimization","generated","unbounded","frequentist","assumption","distribution","alternative","explanation","maximizes","maximally","utilising","functions","investigate","similarity","transformation","distances","correlations","transforms","preserving","transformations","correlated","explicitly","information","phenomena","proposition","expressed","heuristic","extracting","associated","applications","structure","processing","sentences","dependency","uniformly","identifies","violations","logarithmically","obtaining","individual","approximately","adversarial","probability","unfairness","contextual","nevertheless","interventions","optimizing","mahalanobis","quantitative","represent","individuals","practical","conditions","convexity","introducing","considered","artificial","understood","activation","repeatedly","minimizing","recognition","convergence","characterize","stationary"],"y":[26,105,84,53,15,27,40,38,25,76,250,19,43,9,586,9,6,68,567,340,4,886,280,31,394,1,42,159,69,78,821,120,43,17,24,49,73,80,225,13,45,262,36,21,101,90,295,17,24,46,180,21,140,15,148,130,180,41,45,2,270,29,47,161,47,8,141,222,3,603,21,116,30,44,48,24,241,17,67,27,213,12,22,336,130,27,21,9,300,133,31,1,99,740,273,38,71,73,108,211,251,62,195,13,69,14,108,111,185,91,42,68,67,101,14,37,102,403,11,146,200,484,3,169,228,6,143,10,30,15,39,42,107,103,66,163,9,0,68,203,105,25,11,8,4,214,143,152,57,25,19,15,51,48,30,69,718,28,10,22,51,68,105,427,350,296,69,58,23,28,5,2,46,125,37,97,179,1,49,17,5,51,6,77,118,41,127,124,12,45,112,130,19,31,6,37,375,114,59,27],"type":"bar"},{"x":["distortion","robustness","comparing","evaluations","similarly","surprisingly","p ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4497,), (4497, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interacting</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740755);'>Conceptual</span> <span style=''>Spaces</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>applying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorical</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>compositional</span> <span style=''>scheme</span> <span style=''>of</span> <span style=''>6</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740755);'>conceptual</span> <span style=''>space</span> <span style=''>models</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cognition</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>do</span> <span style=''>this</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>category</span> <span style=''>of</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>relations</span> <span style=''>as</span> <span style=''>a</span> <span style=''>new</span> <span style=''>setting</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorical</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>compositional</span> <span style='background-color:rgba(0, 255, 0, 0.925925925925926);'>semantics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>emphasizing</span> <span style=''>the</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740755);'>conceptual</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740755);'>conceptual</span> <span style=''>spaces</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>composite</span> <span style=''>types</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>adjectives</span> <span style=''>and</span> <span style=''>verbs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>this</span> <span style=''>new</span> <span style=''>model</span> <span style=''>on</span> <span style=''>detailed</span> <span style=''>examples</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exponential</span> <span style=''>Family</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>families</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>RKHS</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>in</span> <span style=''>the</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>case</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>the</span> <span style=''>new</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competing</span> <span style=''>approach</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>density</span> <span style=''>model</span> <span style=''>on</span> <span style=''>datasets</span> <span style=''>that</span> <span style=''>exhibit</span> <span style=''>abrupt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transitions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heteroscedasticity</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Coordinate</span> <span style=''>Descent</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Symmetric</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Nonnegative</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorization</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonnegative</span> <span style=''>matrix</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorization</span> <span style=''>(symNMF)</span> <span style=''>is</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonnegative</span> <span style=''>matrix</span> <span style=''>H</span> <span style=''>usually</span> <span style=''>with</span> <span style=''>much</span> <span style=''>fewer</span> <span style=''>columns</span> <span style=''>than</span> <span style=''>A</span> <span style=''>such</span> <span style=''>that</span> <span style=''>A</span> <span style=''>approx</span> <span style=''>HHT</span> <span style=''>SymNMF</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>for</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>schemes</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>that</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>input</span> <span style=''>matrices</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrated</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>and</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>they</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favorably</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>recent</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>methods</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>Dermatological</span> <span style=''>diseases</span> <span style=''>by</span> <span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style=''>common</span> <span style=''>skin</span> <span style=''>ailments</span> <span style=''>to</span> <span style=''>help</span> <span style=''>people</span> <span style=''>without</span> <span style=''>easy</span> <span style=''>access</span> <span style=''>to</span> <span style=''>dermatologists</span> <span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confirmed</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>classify</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style=''>80</span> <span style=''>accuracy</span> <span style=''>on</span> <span style=''>average</span> <span style=''>when</span> <span style=''>primary</span> <span style=''>care</span> <span style=''>doctors</span> <span style=''>are</span> <span style=''>reported</span> <span style=''>to</span> <span style=''>have</span> <span style=''>53</span> <span style=''>success</span> <span style=''>as</span> <span style=''>per</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>Dermatological</span> <span style=''>diseases</span> <span style=''>are</span> <span style=''>common</span> <span style=''>in</span> <span style=''>every</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>and</span> <span style=''>have</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>spectrum</span> <span style=''>in</span> <span style=''>severity</span> <span style=''>With</span> <span style=''>a</span> <span style=''>shortage</span> <span style=''>of</span> <span style=''>dermatological</span> <span style=''>experts</span> <span style=''>being</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>countries</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>can</span> <span style=''>offer</span> <span style=''>timely</span> <span style=''>medical</span> <span style=''>advice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>common</span> <span style=''>skin</span> <span style=''>diseases</span> <span style=''>The</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>nine</span> <span style=''>distinct</span> <span style=''>dermatological</span> <span style=''>diseases</span> <span style=''>which</span> <span style=''>have</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style=''>in</span> <span style=''>East</span> <span style=''>Asian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>countries</span> <span style=''>Our</span> <span style=''>current</span> <span style=''>attemp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12580645161290321)
# 	segmentation (0.06989247311827956)
# 	processing (0.1060931899641577)
# 	experimental (0.14336917562724014)
# 	detection (0.12186379928315412)
# 	representation (0.14121863799283155)
# 	information (0.25734767025089605)
# 	different (0.26523297491039427)
# 	recognition (0.13440860215053763)
# 	convolutional (0.13835125448028673)
#
# Some Statistics words are:
# 	stochastic (0.136318407960199)
# 	variables (0.13084577114427862)
# 	estimation (0.1761194029850746)
# 	statistical (0.15223880597014924)
# 	algorithm (0.4009950248756219)
# 	distribution (0.18159203980099503)
# 	theoretical (0.16019900497512438)
# 	inference (0.19502487562189055)
# 	dimensional (0.1855721393034826)
# 	regression (0.18358208955223881)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8cfe931a-6b55-4953-9210-c0cbc22d0a80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cfe931a-6b55-4953-9210-c0cbc22d0a80")) {                    Plotly.newPlot(                        "8cfe931a-6b55-4953-9210-c0cbc22d0a80",                        [{"x":["distortion","robustness","comparing","evaluations","similarly","surprisingly","perception","recognizing","flexibility","determine","outperforms","degradation","increasingly","annotators","algorithms","deformations","distorted","detecting","demonstrate","detection","paintings","performance","significantly","detectors","representation","fragmentation","recognize","resulting","simulation","iterative","algorithm","regression","connection","smoothness","estimator","validation","dependent","regularization","technique","reproducing","establish","including","parametric","favorably","reduction","observations","available","thresholding","analytical","unlabeled","dimensional","illustrated","constraints","orientations","clustering","synthetic","specifically","simulations","dimensions","undersampling","computational","desirable","requirements","extensive","acquisition","fundamentally","theoretical","complexity","incurring","experiments","subspaces","mechanism","principles","projection","dimensionality","orthogonal","significant","complement","dimension","asymptotic","estimation","lightweight","quadratic","introduce","parameter","arbitrarily","sometimes","asymptotically","optimization","stochastic","converges","linearization","approximate","different","particular","graphical","likelihood","contribution","generative","inference","parameters","expression","segmentation","indicating","achieving","predictors","promising","independent","supervised","conditional","expressions","magnitude","annotations","previously","possibilities","directions","conventional","efficient","problematic","probabilistic","properties","classification","possesses","selection","prediction","composing","statistical","convenient","sophisticated","multivariate","selecting","substantial","generalization","classical","minimization","generated","unbounded","frequentist","assumption","distribution","alternative","explanation","maximizes","maximally","utilising","functions","investigate","similarity","transformation","distances","correlations","transforms","preserving","transformations","correlated","explicitly","information","phenomena","proposition","expressed","heuristic","extracting","associated","applications","structure","processing","sentences","dependency","uniformly","identifies","violations","logarithmically","obtaining","individual","approximately","adversarial","probability","unfairness","contextual","nevertheless","interventions","optimizing","mahalanobis","quantitative","represent","individuals","practical","conditions","convexity","introducing","considered","artificial","understood","activation","repeatedly","minimizing","recognition","convergence","characterize","stationary","necessary","remaining","guarantees","piecewise","considerable","sufficient","seemingly","difficulty","unreasonable","rectifier","objective","interesting","framework","retrieval","multimedia","relationships","integrated","libraries","characteristic","characteristics","modelling","measurements","attractive","unsupervised","presented","associations","investigations","principle","introduced","annotated","increasing","approaches","challenging","convolutional","generator","augmentation","phenotyping","realistic","alleviate","conditioning","containing","limitation","effective","therefore","canonical","advantage","competing","measurement","consequence","emphasizes","effectively","streaming","nontrivial","incorporating","experimental","illustrate","combina ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	frequentist
# 	confounding
# 	nonstationarity
# 	epigenomics
# 	quantiles
# 	functionals
# 	debiasing
# 	precipitation
# 	deflation
# 	embarrassingly
# 	sparsities
# 	uncountable
# 	measurability
# 	multiplayer
# 	simulators
# 	plentiful
# 	cheminformatics
# 	parametrically
# 	lengthscales
# 	semiparametric
# Some words which never appear in Statistics papers:
# 	deformations
# 	paintings
# 	emphasizes
# 	collaboration
# 	argumentative
# 	conversational
# 	dialogues
# 	transducers
# 	compilation
# 	maintainable
# 	morphemes
# 	syntactic
# 	projectors
# 	egomotion
# 	triangulation
# 	monocular
# 	independences
# 	abductive
# 	abduction
# 	rejecting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0867055591567124e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333

# %% [markdown]
# # THANK YOU...
